# %%
#例4.1

# %%
import numpy as np 
import matplotlib.pyplot as plt
x=np.linspace(0,2) #数据个数默认为50
plt.plot(x,x/(1+x),label='y=x/(1+x)')
plt.plot(x,np.log(1+x),label='y=ln(x)')
plt.plot(x,x,label='y=x')
plt.legend()
plt.show()
